# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./wet/weather.csv', sep=';')
df.head()
# Out:
#    Month Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0      1   Albury     20.4     37.6       0.0             54             0
# 1      1   Albury     20.9     33.6       0.4             50             9
# 2      1   Albury     18.4     23.1       2.2             48            11
# 3      1   Albury     17.3     23.7      15.6             39             9
# 4      1   Albury     15.5     22.9       6.8             31             6
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud3pm  \
# 0             7           46           17       1013.4       1009.2         3
# 1            17           54           30       1011.1       1008.4         8
# 2            39           62           67       1014.0       1014.8         8
# 3            17           74           65       1017.9       1016.5         8
# 4             9           92           63       1016.3       1013.9         8
#
#    Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
#Numero di istanze raggruppate per ogni città all
media=df.groupby('Location')['Month'].size()/12
media.plot(kind='bar', figsize=(15,5), title='Numero di istanze raggruppate per ogni città')
# Out:
# <AxesSubplot:title={'center':'Numero di istanze raggruppate per ogni città'}, xlabel='Location'>

# %%
df.groupby(['Location','Month'])['Humidity9am','Humidity3pm'].agg(['min','max'])
# Out:
# C:\Users\dany0\AppData\Local\Temp\ipykernel_21608\1521154956.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Location','Month'])['Humidity9am','Humidity3pm'].agg(['min','max'])
#                Humidity9am     Humidity3pm
#                        min max         min max
# Location Month
# Adelaide 1              14  86          11  93
#          2              30  73          13  76
#          3              36  93          19  65
#          4              24  84          15  58
#          5              36  93          32  92
# ...                    ...  ..         ...  ..
# Woomera  8              28  92          13  78
#          9              24  95          15  84
#          10             10  92           4  62
#          11              6  76           3  46
#          12             15  81           7  57
#
# [497 rows x 4 columns]

# %%
df.head()
# Out:
#    Month Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0      1   Albury     20.4     37.6       0.0             54             0
# 1      1   Albury     20.9     33.6       0.4             50             9
# 2      1   Albury     18.4     23.1       2.2             48            11
# 3      1   Albury     17.3     23.7      15.6             39             9
# 4      1   Albury     15.5     22.9       6.8             31             6
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud3pm  \
# 0             7           46           17       1013.4       1009.2         3
# 1            17           54           30       1011.1       1008.4         8
# 2            39           62           67       1014.0       1014.8         8
# 3            17           74           65       1017.9       1016.5         8
# 4             9           92           63       1016.3       1013.9         8
#
#    Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
df['TemperatureEscursion']=df['MaxTemp']-df['MinTemp']
df.head()
# Out:
#    Month Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0      1   Albury     20.4     37.6       0.0             54             0
# 1      1   Albury     20.9     33.6       0.4             50             9
# 2      1   Albury     18.4     23.1       2.2             48            11
# 3      1   Albury     17.3     23.7      15.6             39             9
# 4      1   Albury     15.5     22.9       6.8             31             6
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud3pm  \
# 0             7           46           17       1013.4       1009.2         3
# 1            17           54           30       1011.1       1008.4         8
# 2            39           62           67       1014.0       1014.8         8
# 3            17           74           65       1017.9       1016.5         8
# 4             9           92           63       1016.3       1013.9         8
#
# ...
